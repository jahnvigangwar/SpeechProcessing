# %%
from playsound import playsound

playsound('C:\Users\acer\Downloads\Sample.wav')
# Out:
#   File "C:\Users\acer\AppData\Local\Temp\ipykernel_4776\3075830585.py", line 3
#     playsound('C:\Users\acer\Downloads\Sample.wav')
#                                                   ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
from playsound import playsound

playsound('C:\\Users\\acer\\Downloads\\Sample.wav')
# Out:
#     Error 305 for command:
#         open "C:\Users\acer\Downloads\Sample.wav"
#     Cannot specify extra characters after a string enclosed in quotation marks.
#
#     Error 305 for command:
#         close "C:\Users\acer\Downloads\Sample.wav"
#     Cannot specify extra characters after a string enclosed in quotation marks.
# Failed to close the file: "C:\Users\acer\Downloads\Sample.wav"
# ---------------------------------------------------------------------------
# PlaysoundException                        Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22128\1774390982.py in <module>
#       1 from playsound import playsound
#       2
# ----> 3 playsound('C:\\Users\\acer\\Downloads\\Sample.wav')
#
# ~\AppData\Roaming\Python\Python39\site-packages\playsound.py in _playsoundWin(sound, block)
#      70     try:
#      71         logger.debug('Starting')
# ---> 72         winCommand(u'open {}'.format(sound))
# ...

# %%
from playsound import playsound

playsound('C:\\Users\\acer\\Downloads\\WaterAMetalTroughX2 TE36432.wav')

# %%
import numpy as np
import matplotlib.pyplot as plt
# Sample rate (number of samples per second)
sample_rate = 44100

# Time values in seconds
time = np.arange(0, 1, 1/sample_rate)

# Frequency of the speech signal (e.g., 440 Hz for an 'A' sound)
frequency = 220

# Generate the speech signal (a sine wave in this case)
speech_signal = np.sin(2 * np.pi * frequency * time)
fig, ax = plt.subplots()

# Plot the speech signal waveform
ax.plot(time, speech_signal)

# Set labels for the axes and the title for the plot
ax.set_xlabel('Time (seconds)')
ax.set_ylabel('Amplitude')
ax.set_title('Speech Signal Waveform')

# Show the plot
plt.show()

# %%
pip install numpy matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\acer\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\acer\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\acer\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\acer\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\acer\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\acer\appdata\roaming\python\python39\site-packages)

# %%
pip install scipy numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\acer\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\acer\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\acer\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\acer\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\acer\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\acer\appdata\roaming\python\python39\site-packages)

# %%
import scipy.io.wavfile as wav
import numpy as np
sample_rate, audio_data = wav.read('C:\\Users\\acer\\Downloads\\WaterAMetalTroughX2 TE36432.wav')

import matplotlib.pyplot as plt

# Time values in seconds
time = np.arange(len(audio_data)) / sample_rate

# Create the figure and axes for the plot
fig, ax = plt.subplots()

# Plot the speech signal waveform
ax.plot(time, audio_data)

# Set labels for the axes and the title for the plot
ax.set_xlabel('Time (seconds)')
ax.set_ylabel('Amplitude')
ax.set_title('Speech Signal Waveform')

# Show the plot
plt.show()
# Out:
# C:\Users\acer\AppData\Local\Temp\ipykernel_4776\1460992116.py:3: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sample_rate, audio_data = wav.read('C:\\Users\\acer\\Downloads\\WaterAMetalTroughX2 TE36432.wav')

# %%
pip install librosa matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\acer\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\acer\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\acer\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\acer\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\acer\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\acer\appdata\roaming\python\python39\site-packages)
# ...

# %%
import librosa
import matplotlib.pyplot as plt

# %%
audio_path = 'C:\\Users\\acer\\Downloads\\Sample.wav'
y, sr = librosa.load(audio_path)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4776\2252227025.py in <module>
#       1 audio_path = 'C:\\Users\\acer\\Downloads\\Sample.wav'
# ----> 2 y, sr = librosa.load(audio_path)
#
# ~\AppData\Roaming\Python\Python39\site-packages\lazy_loader\__init__.py in __getattr__(name)
#      76             submod_path = f"{package_name}.{attr_to_modules[name]}"
#      77             submod = importlib.import_module(submod_path)
# ---> 78             attr = getattr(submod, name)
#      79
#      80             # If the attribute lives in a file (module) with the same
#
# ~\AppData\Roaming\Python\Python39\site-packages\lazy_loader\__init__.py in __getattr__(name)
#      75         elif name in attr_to_modules:
#      76             submod_path = f"{package_name}.{attr_to_modules[name]}"
# ...

# %%
audio_path = 'C:\\Users\\acer\\Downloads\\Sample.wav'

# %%
audio_path = 'C:\\Users\\acer\\Downloads\\Sample.wav'
y, sr = librosa.load(audio_path)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4776\2252227025.py in <module>
#       1 audio_path = 'C:\\Users\\acer\\Downloads\\Sample.wav'
# ----> 2 y, sr = librosa.load(audio_path)
#
# ~\AppData\Roaming\Python\Python39\site-packages\lazy_loader\__init__.py in __getattr__(name)
#      76             submod_path = f"{package_name}.{attr_to_modules[name]}"
#      77             submod = importlib.import_module(submod_path)
# ---> 78             attr = getattr(submod, name)
#      79
#      80             # If the attribute lives in a file (module) with the same
#
# ~\AppData\Roaming\Python\Python39\site-packages\lazy_loader\__init__.py in __getattr__(name)
#      75         elif name in attr_to_modules:
#      76             submod_path = f"{package_name}.{attr_to_modules[name]}"
# ...

# %%
import librosa
audio_path='C:\\Users\\acer\\Downloads\\Sample.wav'
y, sr = librosa.load(audio_path, sr=44100, mono=False)

# %%
audio_path = 'C:\\Users\\acer\\Downloads\\Sample.wav'
y, sr = librosa.load(audio_path)

# %%
rms = librosa.feature.rms(y=y)

# %%
plt.title('rms')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22128\600076634.py in <module>
# ----> 1 plt.title('rms')
#       2 plt.show()
#
# NameError: name 'plt' is not defined

# %%
zcr = librosa.feature.zero_crossing_rate(y=y)
centroid = librosa.feature.spectral_centroid(y=y, sr=sr)
bandwidth = librosa.feature.spectral_bandwidth(y=y, sr=sr)
contrast = librosa.feature.spectral_contrast(y=y, sr=sr)
chroma = librosa.feature.chroma_stft(y=y, sr=sr)
rms = librosa.feature.rms(y=y)

# %%
from matplotlib import pyplot as plt
plt.figure(figsize=(10, 6))
librosa.display.specshow(contrast, x_axis='time', sr=sr)
plt.colorbar()
plt.title('contrast')
plt.show()

# %%
print("RMS Energy:", rms)
print("Zero Crossing Rate:", zcr)
print("Spectral Centroid:", centroid)
print("Spectral Bandwidth:", bandwidth)
print("Spectral Contrast:", contrast)
print("Chroma Features:", chroma)
# Out:
# RMS Energy: [[6.30422756e-02 8.73350352e-02 1.02791578e-01 1.02230974e-01
#   8.29196721e-02 7.84716383e-02 8.28396454e-02 1.01109214e-01
#   1.05860658e-01 9.11157876e-02 7.85590336e-02 7.86312670e-02
#   9.43493098e-02 1.05432846e-01 9.85918641e-02 7.86068514e-02
#   7.82517791e-02 8.70666206e-02 1.03870593e-01 1.05478145e-01
#   8.65388289e-02 7.83478841e-02 8.07982311e-02 9.86480340e-02
#   1.05755508e-01 9.42609459e-02 7.85572752e-02 7.95758143e-02
#   9.27714184e-02 1.06347948e-01 1.02512099e-01 8.19240361e-02
#   7.84507766e-02 8.43628123e-02 1.02448322e-01 1.05882026e-01
#   8.97096246e-02 7.84190521e-02 7.88072571e-02 9.58779156e-02
#   1.05624959e-01 9.71024483e-02 7.61429444e-02 4.57807370e-02
#   1.04202544e-02 4.03426168e-03 2.74359714e-03 1.56642229e-03
#   5.16805984e-02 7.92490691e-02 9.96080860e-02 1.05495833e-01
#   9.21932533e-02 7.82350302e-02 7.87466764e-02 9.31497961e-02
#   1.05258219e-01 1.00006789e-01 7.92719275e-02 7.81916901e-02
# ...
